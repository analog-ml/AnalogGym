# %% [markdown]
# - Installing ngspicehttps://web02.gonzaga.edu/faculty/talarico/vlsi/ngspice.html

# %% [markdown]
# When AMP_NMCF.py run the simulation, it will generate the following two files: `AMP_NMCF_ACDC.log` and `AMP_NMCF_Tran.log`
#
# ```python
# os.system(f'cd {SPICE_NETLIST_DIR}&& ngspice -b -o AMP_NMCF_ACDC.log AMP_NMCF_ACDC.cir')
# os.system(f'cd {SPICE_NETLIST_DIR}&& ngspice -b -o AMP_NMCF_Tran.log AMP_NMCF_Tran.cir')
# ```
#
# And the following three files: `AMP_NMCF_ACDC_DC` , `AMP_NMCF_ACDC_AC` and `AMP_NMCF_ACDC_GBW_PM` as specified in the `AMP_NMCF_ACDC.cir`
#
#
# → Total of 5 log files will be created !

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### AMP_NMCF_ACDC_DC
#
# Column names: Temp_dc, TC_dc, Power_dc, vos_dc
#
# - TC_dc: Calculates temperature coefficient TC
# - Power_dc: Measures supply current at 25°C, Calculates power in µW
# - Offset voltage = Output - expected value

# %% [markdown]
# **🔄 What is DC Sweep in SPICE?**
#
# A DC Sweep is a type of SPICE analysis that systematically varies a DC source (voltage or current) over a defined range and records the circuit's steady-state response at each step. It’s essentially a way to perform parametric simulation on a DC source.
#
# **✅ Why Use a DC Sweep?**
# - To study input-output characteristics (e.g., voltage transfer curves).
#
# - To observe bias point movement across a range of supply or input voltages.
#
# - To verify linearity, thresholds, gain, or saturation points.
#
# - To check behavior across temperature (if temperature is swept).
#
# **🧾 Syntax Summary**
# - Sweep temperature: `DC temp START STOP STEP`

# %% [markdown]
# ### AMP_NMCF_ACDC_AC
#
# Column names: freq, cmrrdc_ac, PSRP_ac, PSRN_ac, dcgain_ac

# %% [markdown]
# ### AMP_NMCF_ACDC_GBW_PM
#
# Column names: freq, GBW_ac, phase_margin_ac
